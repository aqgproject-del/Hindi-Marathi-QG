# %% [markdown]
# <a href="https://colab.research.google.com/github/aqgproject-del/Hindi-Marathi-QG/blob/main/00_Input_Handler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Automatic Question Generation for Hindi and Marathi

## Notebook 0 : Input Handler

### Objective

###This notebook accepts different input file formats (.txt, .pdf, .docx, .doc),
###detects the uploaded file type automatically,extracts the text,and saves it as clean_text.txt for further NLP processing.###

# %%
# !pip install pymupdf python-docx textract
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (1.28.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: textract in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.1.1)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.16.0)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from textract) (11.3.0)
# Requirement already satisfied: speechrecognition>=3.8.1 in /usr/local/lib/python3.12/dist-packages (from textract) (3.17.0)
# Requirement already satisfied: argcomplete>=3.6.3 in /usr/local/lib/python3.12/dist-packages (from textract) (3.7.2)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from textract) (4.13.5)
# Requirement already satisfied: chardet>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from textract) (5.2.0)
# Requirement already satisfied: docx2txt>=0.8 in /usr/local/lib/python3.12/dist-packages (from textract) (0.9)
# Requirement already satisfied: extract-msg>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from textract) (0.56.0)
# Requirement already satisfied: pdfminer-six>=20221105 in /usr/local/lib/python3.12/dist-packages (from textract) (20260107)
# Requirement already satisfied: python-pptx>=0.6.18 in /usr/local/lib/python3.12/dist-packages (from textract) (1.0.2)
# Requirement already satisfied: xlrd<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from textract) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8.0->textract) (2.8.4)
# Requirement already satisfied: olefile==0.47 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (0.47)
# Requirement already satisfied: tzlocal<6,>=4.2 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (5.4.4)
# Requirement already satisfied: compressed-rtf<2,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (1.0.7)
# Requirement already satisfied: ebcdic<3,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (2.0.1)
# Requirement already satisfied: RTFDE<0.2,>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (0.1.2.2)
# Requirement already satisfied: red-black-tree-mod<=1.23,>=1.20 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (1.22)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20221105->textract) (3.4.9)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20221105->textract) (49.0.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from python-pptx>=0.6.18->textract) (3.2.9)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20221105->textract) (2.1.0)
# Requirement already satisfied: lark~=1.3.0 in /usr/local/lib/python3.12/dist-packages (from RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (1.3.1)
# Requirement already satisfied: oletools>=0.56 in /usr/local/lib/python3.12/dist-packages (from RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (0.60.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20221105->textract) (3.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (3.3.2)
# Requirement already satisfied: easygui in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (0.98.3)
# Requirement already satisfied: colorclass in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (2.2.2)
# Requirement already satisfied: pcodedmp>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (1.2.6)
# Requirement already satisfied: msoffcrypto-tool in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (6.0.0)

# %%
import os
import pymupdf
from docx import Document

from google.colab import drive

# %%
drive.mount('/content/drive')
input_file = "/content/drive/MyDrive/datasets_dummy.pdf"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_extension = os.path.splitext(input_file)[1].lower()

print("Detected File Type :", file_extension)
# Out:
# Detected File Type : .pdf

# %%
def extract_txt(path):

    with open(path, "r", encoding="utf-8") as file:
        return file.read()

# %%
def extract_pdf(path):

    document = pymupdf.open(path)

    text = ""

    for page in document:
        text += page.get_text()

    return text

# %%
def extract_docx(path):

    document = Document(path)

    text = ""

    for para in document.paragraphs:
        text += para.text + "\n"

    return text

# %%
if file_extension == ".txt":

    text = extract_txt(input_file)

elif file_extension == ".pdf":

    text = extract_pdf(input_file)

elif file_extension == ".docx":

    text = extract_docx(input_file)

elif file_extension == ".doc":

    raise ValueError("Please convert .doc to .docx before processing.")

else:

    raise ValueError("Unsupported File Type")

# %%
output_path = "/content/drive/MyDrive/AQG/extracted_text.txt"

with open(output_path, "w", encoding="utf-8") as file:
    file.write(text)

print("extracted_text.txt created successfully!")
# Out:
# extracted_text.txt created successfully!
